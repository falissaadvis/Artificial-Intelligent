# %%
import pandas as pd   # Untuk manipulasi dan analisis data
import numpy as np    # Untuk operasi numerik
import matplotlib.pyplot as plt # Untuk visualisasi grafik
import seaborn as sns # Untuk visualisasi statistik yang lebih estetis
from sklearn.cluster import KMeans  # Algoritma K-Means Clustering

# %%
# Membaca file CSV
dataset = pd.read_csv("Mall_Customers.csv")
dataset.head()  # Menampilkan 5 baris pertama untuk melihat struktur data
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Hanya mengambil fitur "Annual Income" dan "Spending Score"
X = dataset.iloc[:, 3:5] # 3:5 artinya adalah mengambil kolom index 3 sampai 4 (atau 5-1)
X.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# Ukuran data (kolom, baris)
X.shape
# Out:
# (200, 2)

# %%
# Cek data missing
X.isnull().sum()
# Out:
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Ringkasan data
X.describe()
# Out:
#        Annual Income (k$)  Spending Score (1-100)
# count          200.000000              200.000000
# mean            60.560000               50.200000
# std             26.264721               25.823522
# min             15.000000                1.000000
# 25%             41.500000               34.750000
# 50%             61.500000               50.000000
# 75%             78.000000               73.000000
# max            137.000000               99.000000

# %%
# Menentukan jumlah cluster optimal
# random_state=14 → agar hasil konsisten setiap kali dijalankan
# inertia_ adalah atribut sklearn yang menyimpan nilai WCSS
wcss = [] # wcss -> Within Cluster Sum of Squares
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, random_state = 14)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Visualisasi Metode Elbow
plt.plot(range(1, 15), wcss)
plt.title("The Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
